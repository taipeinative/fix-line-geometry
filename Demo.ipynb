# %%
from FixLineGeometry import FixLineGeometry

url = 'test.shp'
shapefile = FixLineGeometry(url)
shapefile.plot()

# %%
shapefile.debug(True)
# Out:
# ...
# Searching nearest vertices: 100%|██████████| 82/82 [00:01<00:00, 44.76it/s]
#      index     name  nbr_idx0  nbr_idx1 nbr_name  \
# 0      177  捷運淡水信義線         1         0  捷運淡水信義線
# 1      451  捷運淡水信義線         1         0  捷運淡水信義線
# 3        3      NaN         1         2  捷運淡水信義線
# 4        6  捷運淡水信義線         1         2  捷運淡水信義線
# 6        3      NaN         5         0  捷運淡水信義線
# ..     ...      ...       ...       ...      ...
# 220    397    捷運板南線       581         2   台灣高速鐵路
# 227    606      NaN       583         4   台灣高速鐵路
# 228    437   台灣高速鐵路       605         0      NaN
# 229    437   台灣高速鐵路       606         1      NaN
# 231    487   台灣高速鐵路       606        10      NaN
#
#                                           nbr_poin  \
# 0     POINT (302219.4804491473 2769633.8675887506)
# 1     POINT (302219.4804491473 2769633.8675887506)
# 3      POINT (302306.478332293 2769507.8929093457)
# 4      POINT (302306.478332293 2769507.8929093457)
# ...

# %%
new_shapefile = FixLineGeometry('fixed.shp')
new_shapefile.plot()

# %%
new_shapefile.debug(True)
# Out:
# ...
# Searching nearest vertices: 100%|██████████| 38/38 [00:01<00:00, 30.93it/s]
#      index     name  nbr_idx0  nbr_idx1 nbr_name  \
# 0        6  捷運淡水信義線         5         1  捷運淡水信義線
# 2      409  捷運淡水信義線         5        58  捷運淡水信義線
# 7       22  捷運松山新店線        21         1  捷運松山新店線
# 13      80  捷運中和新蘆線        23         5  捷運松山新店線
# 14      33  捷運松山新店線        30         3  捷運松山新店線
# 15      63      NaN        32         0  捷運松山新店線
# 16      62  捷運松山新店線        32         1  捷運松山新店線
# 18      59  捷運松山新店線        34         3  捷運松山新店線
# 21      63      NaN        58         0      NaN
# 24      81  捷運中和新蘆線        80         0  捷運中和新蘆線
# 25      82  捷運松山新店線        80         0  捷運中和新蘆線
# 28     178  捷運中和新蘆線        81         0  捷運中和新蘆線
# 33     178  捷運中和新蘆線        82         5  捷運松山新店線
# 36     581   台灣高速鐵路       175         3   縱貫線西正線
# 37     440   台灣高速鐵路       175         5   縱貫線西正線
# 40     487   台灣高速鐵路       192         0   縱貫線東正線
# 43     543   台灣高速鐵路       199         4   縱貫線西正線
# ...
